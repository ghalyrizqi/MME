# %%
import os
print(os.getenv('SPOTIFY_CLIENT_ID'))
print(os.getenv('SPOTIFY_CLIENT_SECRET'))
# Out:
# 121584c859934f37b9ff08c7f3d63543
# 0c972ab9110446a3a7b6fd2a0c2b1551

# %%
# spotify doang
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

class MusicMetadataRetriever:
    def __init__(self, spotify_client_id, spotify_client_secret):
        """
        Initialize the music metadata retriever with Spotify API credentials
        
        :param spotify_client_id: Spotify API Client ID
        :param spotify_client_secret: Spotify API Client Secret
        """
        # Spotify Client Setup
        self.spotify_client_credentials_manager = SpotifyClientCredentials(
            client_id=spotify_client_id, 
            client_secret=spotify_client_secret
        )
        self.spotify_client = spotipy.Spotify(
            client_credentials_manager=self.spotify_client_credentials_manager
        )
    
    def search_spotify_track(self, track_name, artist_name):
        """
        Search for a track on Spotify and retrieve its metadata
        """
        try:
            results = self.spotify_client.search(
                q=f'track:{track_name} artist:{artist_name}', 
                type='track', 
                limit=1
            )
            if results['tracks']['items']:
                track = results['tracks']['items'][0]
                return {
                    'spotify_track_id': track['id'],
                    'isrc': track['external_ids'].get('isrc', 'N/A'),
                    'track_name': track['name'],
                    'artist_name': track['artists'][0]['name'],
                    'album_name': track['album']['name'],
                    'release_date': track['album']['release_date']
                }
            return None
        except Exception as e:
            print(f"Error searching Spotify track: {e}")
            return None
    
    def retrieve_track_metadata(self, tracks):
        """
        Retrieve metadata for multiple tracks from Spotify
        """
        metadata_results = []
        for track_info in tracks:
            track_name = track_info.get('track_name')
            artist_name = track_info.get('artist_name')
            print(f"Processing track: {track_name} by {artist_name}...")
            
            spotify_metadata = self.search_spotify_track(track_name, artist_name)
            
            combined_metadata = {
                'track_name': track_name,
                'artist_name': artist_name,
                **((spotify_metadata or {}) if spotify_metadata else {})
            }
            metadata_results.append(combined_metadata)
        return pd.DataFrame(metadata_results)

def main():
    # Load environment variables for credentials
    SPOTIFY_CLIENT_ID = os.getenv('SPOTIFY_CLIENT_ID')
    SPOTIFY_CLIENT_SECRET = os.getenv('SPOTIFY_CLIENT_SECRET')
    
    # Initialize retriever
    retriever = MusicMetadataRetriever(
        SPOTIFY_CLIENT_ID, 
        SPOTIFY_CLIENT_SECRET
    )

    # Load CSV file as track input
    csv_file_path = '[DE TS] Song Catalog Data - Data.csv'
    try:
        # Load the CSV file
        song_data = pd.read_csv(csv_file_path)
        print("CSV file loaded successfully!")
        
        # Rename columns to match the required format
        tracks_to_search = song_data.rename(columns={
            'ORIGINAL ARTIST': 'artist_name',
            'SONG TITLE': 'track_name'
        })[['track_name', 'artist_name']].dropna()
        
        print("Formatted track list for search:")
        print(tracks_to_search.head())
        
    except Exception as e:
        print(f"Error loading CSV file: {e}")
        return
    
    # Retrieve metadata
    metadata_df = retriever.retrieve_track_metadata(tracks_to_search.to_dict('records'))
    print(metadata_df)

    # Save to CSV
    output_file = 'combined_spotify_metadata.csv'
    metadata_df.to_csv(output_file, index=False)
    print(f"Metadata saved to {output_file}")

if __name__ == '__main__':
    main()
# Out:
# CSV file loaded successfully!
# Formatted track list for search:
#                            track_name artist_name
# 0                      BERTAHAN HIDUP      8 BALL
# 4                              KEMANA   KOES PLUS
# 10                     TARI SELENDANG   KOES PLUS
# 11  MAIN THEME FROM 13 BOM DI JAKARTA  ABEL HURAY
# 12               TANGISAN IBU PERTIWI   STRANGERS
# Processing track: BERTAHAN HIDUP by 8 BALL...
# Processing track: KEMANA by KOES PLUS...
# Processing track: TARI SELENDANG by KOES PLUS...
# Processing track: MAIN THEME FROM 13 BOM DI JAKARTA by ABEL HURAY...
# Processing track: TANGISAN IBU PERTIWI by STRANGERS...
# Processing track: TIDAK ADA SALJU DI SINI PT 4 by HINDIA...
# Processing track: INI INDONESIA by MIKHA TAMBAYONG...
# Processing track: TANDA MATA by GLENN FREDLY...
# Processing track: DIA KEKASIHKU by NAFF...
# Processing track: KARENAMU by ARI PRAMUNDITO...
# Processing track: WARTEG (WARGA TEGAR) by 8 BALL...
# Processing track: SAMARI PUANG by DANIEL TANDIROGANG...
# Processing track: SENDIRI DAN RAHASIA by KOES PLUS...
# Processing track: INEVITABLE by ALSA, CHRIS ANDRIAN YANG...
# Processing track: DITES VOTRE AMOUR by 8 BALL...
# Processing track: KERETA by JANUARY CHRISTY...
# Processing track: WHERE IS YOUR HEART by DIOSDU...
# Processing track: HONESTLY I DONT by DIDIT SAAD...
# Processing track: ASMALIBRASI by SOEGI BORNEAN...
# Processing track: SENSUAL IMITASI by 8 BALL...
# Processing track: KASIHNYA by HENKIE SAHURILLA...
# Processing track: SETENGAH HATI by AINAN TASNEEM...
# Processing track: COLDROOM by CLOSURE...
# Processing track: WE ARE BROTHER by MOMONON...
# Processing track: LAGU WANITA by NAIF...
# Processing track: TATANAN ATI by SASYA ARKHISNA...
# Processing track: ADIK PANDAI BERJALAN by KOES PLUS...
# Processing track: NGANTI KURU by DIDI KEMPOT...
# Processing track: DUA RAJA SATU HATI by JUSTY ALDRIN & RINA SAINYAKIT...
# Processing track: LAURIE WEBB by THE SKIBERS...
# Processing track: JALAN HIDUPKU by ADA BAND...
# Processing track: SECRET INVASION by LOTUS FROM JAKARTA...
# Processing track: RISE by APE ON THE ROOF...
# Processing track: RASA YANG SALAH by HAPPY ASMARA, RAY SHARIR...
# Processing track: SELAMAT BERBAHAGIA DENGANNYA by ARSHA COMPOSER...
# Processing track: AKU TANPAMU by MAIZURA...
# Processing track: BERONA by RIZKY FEBIAN...
# Processing track: JBAML (JANGAN BUAT AKU MENUNGGU LAMA) by CYA...
# Processing track: YOU by ASTERISKA...
# Processing track: BATU GIOK PERLU DIASAH / YI PU CUOK PU JEN JI by NADA TAO...
# Processing track: SAMA by ANDREA MIRANDA FEAT TEZA SUMENDRA...
# Processing track: TEH DINGIN by MOMONON...
# Processing track: EKSPEDISI 69 by KELOMPOK PENERBANG ROKET...
# Processing track: ROSO PANGROSO ( SINOM SASTRO GENDHING ) by DAMAR MURUP...
# Processing track: MATI RASA by BRIGITA TAN...
# Processing track: NYANYIAN KWAN KONG / KWAN SEN MIAU CE KE by NADA TAO...
# Processing track: DONT WANNA LOSE YOU by RISIN BLACK HOLE...
# Processing track: PAPER HEART by RENDY PANDUGO...
# Processing track: MALAM MINGGU DI TAMAN by DIDITSAAD...
# Processing track: BINTANG TERTUTUP AWAN by GUNAWAN LIDA...
# Processing track: LOCKDOWN SYNDROME by MIKA RAFELLO...
# Processing track: HUJAN by MONKEY TO MILLIONAIRE...
# Processing track: DI UJUNG JALAN by SAMSONS...
# Processing track: ELEGI by FIGURA RENATA...
# Processing track: LAGU KESEPIAN by EFEK RUMAH KACA...
# Processing track: NAME UP by TOTON CARIBO FT. GERVLDO19XX...
# Processing track: SUATU PERSEMBAHAN CINTA by CHRISYE...
# Processing track: GELISAH by JUNNO...
# Processing track: CLOSE MY EYES by INDRAGERSN...
# Processing track: PADA SAATNYA NANTI by NINA...
# Processing track: BERAKHIR DENGAN SENYUMAN by 7 KURCACI...
# Processing track: HIDUP by CARELESS 061...
# Processing track: KENANGAN TERINDAH by SAMSONS...
# Processing track: DANKE PAR ALE by ISHAK RANTE TODING...
# Processing track: DOSA APA by NAFF...
# Processing track: DI RUMAH SAJA by HOALA & KOALA...
# Processing track: TETAPLAH DI SINI by TAMI AULIA...
# Processing track: YO CA KANCAH SHOLAWAT BUSYRO by SYUBBANUL MUSLIMIN...
# Processing track: TAK SANDING SLIRAMU by PAKDHE BAZ / DHE BAZ...
# Processing track: UNTUK APA by DHIRA BAND...
# Processing track: CINTA APA ADANYA by RIDWAN...
# Processing track: PUTRI IKLAN by ST12...
# Processing track: BOHONG by BIGWAVE...
# Processing track: JANGAN RAGU by 8 BALL...
# Processing track: API DAN LENTERA by BARASUARA...
# Processing track: SEPERTI HUTAN by RABEN...
# Processing track: KAN KU SONGSONG HARI ESOK by KOES PLUS...
# Processing track: AKU BAIK-BAIK SAJA by THE CHRONICLES OF HAPPINESS RIDE AND SERVICES...
# Processing track: ⁠SEROTONIN 6 AM by INDRA7...
# Processing track: APA ADANYA by HIVI!...
# Processing track: BULAN by LA LUNA...
# Processing track: DREAMIN OF YOU by GANGGA...
# Processing track: JANGAN SEMUDAH INI by RUTH SAHANAYA...
# Processing track: 怀念家乡 (MISS MY HOMETOWN) by ALENA WU...
# Processing track: BERSAMAMU AKU SENANG by ANDY HISTORI...
# Processing track: SEMINGGU by GANGSTARASTA...
# Processing track: SERIBU TAHUN LAGI by ONEWAY...
# Processing track: MENUNGGU APALAGI by EXOTHEBAND feat DEKKA MAYO , KENATHA...
# Processing track: BUMI, BULAN, MATAHARI by DEABDIL...
# Processing track: SEMPURNA UNTUK KU by BOWO...
# Processing track: AMPUNI AKU by DAMON KOESWOYO...
# Processing track: DINDA KECIL by DZEE, CANDRA KIM...
# Processing track: PURNAMA by BILAL INDRAJAYA...
# Processing track: DONT NEED LOVE by ATLESTA...
# Processing track: BILANG I LOVE YOU by SOULJAH...
# Processing track: DIAM (JANGAN BERSUARA) by KIDNAP KATRINA...
# Processing track: MULIA by BOBBY FEBIAN...
# Processing track: SUDAHI MARAHMU by ANANG DAN KRISDAYANTI...
# Processing track: IN YOUR HEAD by ALEX KUPLE...
# Processing track: HERE WITH ME by ALENA WU...
# Processing track: BUNGA HATI by NAIF...
# Processing track: TENTANG LAGU by GOOD OL DREAMS...
# Processing track: PERASAAN CINTAKU by KOES PLUS...
# Processing track: HOYONG KASALIRA by IGOY JANGKUNG...
# Processing track: PELESIRAN by OCTOBER RAIN...
# Processing track: BEDA BAHAGIA by HI.JO...
# Processing track: PUTUS by GOLDFACE...
# Processing track: CERITA KITA by WILLY ANGGAWINATA & BRIGITTA TIFANNY...
# Processing track: KITA ADALAH SATU by BIMBO...
# Processing track: NANDUR LORO by ABIEM PANGESTU FEAT ESA RISTY...
# Processing track: LOST IN THE BLACK HOLE by ARI AMNAN...
# Processing track: I THOUGHT IT WAS CLEAR by ARNANDO PUTRA, CHIEMI YOSHIDA, JUNNA ADACHI...
# Processing track: CERITAKU by VOPSTFM...
# Processing track: LINE TODAY NEWS by SAYKOJI & SHERYL...
# Processing track: BERDIRI by GERAP GURITA...
# Processing track: BARA CINTA by COKI & THE BLUR AMBIENCE...
# Processing track: BELANDA MASIH JAUH by PATRIA NK...
# Processing track: SEMESTINYA by SARAH AZHARI...
# Processing track: CIRCUS by SKINNYFABS...
# Processing track: LUKA by KOES PLUS...
# Processing track: INDONESIAKU by FRANDY, BESTA BLOOM...
# Processing track: SENDIRI DULU by LA HILA...
# Processing track: UANG KULIAH TINGGI by ANGEST...
# Processing track: AKULAH YANG MENCINTAIMU by GALYAS...
# Processing track: AMPUNI AKU by CINTA HARICI...
# Processing track: HEART BEAT SLOW by NOIN BULLET...
# Processing track: KUPERCAYA SALIBMU by JESUS INSIDE MUSIC...
# Processing track: UNTUK INDONESIA by BAGUS ANANDA...
# Processing track: THE WAY TO GO by FAYE RISAKOTTA...
# Processing track: DU DU DU by KOES PLUS...
# Processing track: THE THIRD COMING by THE SKIBERS...
# Processing track: DOA by UNGU...
# Processing track: BERSAMAMU by BAIM...
# Processing track: PERKARA TUBUH by HINDIA...
# Processing track: JANGAN USAI by KRISDAYANTI...
# Processing track: BERNYANYI SAMBIL MENARI by KOES PLUS...
# Processing track: HATIKU HATIMU by KOES PLUS...
# Processing track: TAHAN NAPSU by KOJEK...
# Processing track: RAMADHAN SYAHRU SYIAM by DIAN AGUSTIN...
# Processing track: JAUHARI by OLLY OXEN...
# Processing track: HASRAT DIRI by AZIZ DHANU...
# Processing track: KETIKA AKU DI KETIKA by MIKA RAFELLO...
# Processing track: BISAKAH TANPAMU by TRI SUAKA...
# Processing track: BUTTERFLY by CALISTA AMADEA...
# Processing track: PLEASE by DODDIE, TONGKIE...
# Processing track: SESISIH MOTO by PAKDHE BAZ...
# Processing track: TERENDAP LARAKU by NAFF...
# Processing track: QUANTUM CINTA by FYN...
# Processing track: YOU KNOW by KENNY FEAT SARA FAJIRA...
# Processing track: INDAH PADA WAKTUNYA (FEAT. IRENE REJOICE) by DELON, IRENE REJOICE...
# Processing track: THE BOY IN LOVE by ANDRE HARIHANDOYO...
# Processing track: RELAX by DIPAREYNARDI...
# Processing track: MASS MEDIA by DJAKA BIMBO...
# Processing track: ALL OF EM by TEDDY ADHITYA...
# Processing track: ANJELIE by FLANELLA...
# Processing track: YUNI YUNI by DIDI KEMPOT...
# Processing track: 100 KM/JAM by THE BRANDALS...
# Processing track: APA BISA by DELISHA OKTA...
# Processing track: TUNGGU SEJENAK by ANGGA CANDRA...
# Processing track: SILENCE by ALEX KUPLE...
# Processing track: NAYKILLA by DESTROY YOU (AGAIN)...
# Processing track: HARMONI ALAM by RIDA RSD...
# Processing track: WHAT ABOUT US? by IFY ALYSSA...
# Processing track: TANPA BANYAK BICARA by NATHANIA WIBOWO...
# Processing track: PAK TANI by KOES PLUS...
# Processing track: SA AE LAU by SEXY GOATH, BONIE MC...
# Processing track: HAPPY BIRTHDAY by MKARTIKAWATI...
# Processing track: LUNGO NINGGAL CERITO by ARIBOWOID, NITA REVIANA...
# Processing track: SELAMAT TINGGAL by SAMSONS...
# Processing track: DOA by DANIEL RUMBEKWAN...
# Processing track: MAAFKAN AKU by KOES PLUS...
# Processing track: BORING by POP UP...
# Processing track: JUMPA 123 by KOES PLUS...
# Processing track: DENGAR BISIKKU by THE RAIN...
# Processing track: NELANGSA by NAFF...
# Processing track: SANG SURYA by NO KOES...
# Processing track: WAYAHNA LUR by PANDEGLANG VARIOUS ARTIST...
# Processing track: MATAHARI by NATASHA...
# Processing track: MELANKOLI KOTA by BUNGEN...
# Processing track: TERKETUK CINTA by JAKA ROHMANA...
# Processing track: KITA (SEKEDAR PESAN) by EZZAR...
# Processing track: TANGAN KECIL by FIGURA RENATA...
# Processing track: SALAHKAH BERBEDA by NEAR FEAT NINO MINGGO, YENNY KABUPUNG...
# Processing track: CINTA PERTAMA by GAMMA1...
# Processing track: METAMORFOSA by ANDIEN...
# Processing track: CEMBURU by LA LUNA...
# Processing track: TERLALU CINTA by NUMATA...
# Processing track: MUAK by KIDNAP KATRINA...
# Processing track: MASIH MENCINTAIMU by GRUVI...
# Processing track: LAMENT. by VICTOR PRADIPTA...
# Processing track: PESONA PERSONA by THE ADAMS...
# Processing track: HATI YANG LAIN by THE45...
# Processing track: KARMA by ZEROSIX PARK...
# Processing track: RADAR by CHAI...
# Processing track: UJANG DKK by MR JARWO...
# Processing track: UKHUWAH ACAPELLA by MUSLIH...
# Processing track: AMBER by OTTA TARREGA...
# Processing track: RUNNIN by NOWELA MIKHELIA...
# Processing track: RIBUAN SAYA by JUNIOR SOEMANTRI...
# Processing track: ISTIMEWA by ARSHA COMPOSER...
# Processing track: EPILOG by FIERSA BESARI...
# Processing track: TAK PERLU MEMILIKI by RIDA,SITA,DEWI...
# Processing track: SUDAHI SAJA by TAKE OVER X JHON PAUL IVAN...
# Processing track: RAHASIA by PONGKI BARATA...
# Processing track: MARI-MARI by KOES PLUS...
# Processing track: TETAP SETIA by LA LUNA...
# Processing track: REAL TALK by RABEN...
# Processing track: RASA DI HATIKU by ISHAK RANTE TODING...
# Processing track: NO MORE by PERFECTA...
# Processing track: HILANG TAPI ADA by JUDIKA...
# Processing track: PLONG by DIDI KEMPOT...
# Processing track: ADIKKU MANIS by CHICHA KOESWOYO...
# Processing track: ON YOUR BIRTHDAY by THE RENTENIR...
# Processing track: LAGU RINDU by DITA...
# Processing track: TAK LAGI SAMA by MADAHARSA...
# Processing track: KAU by THE GREAT HARVEST...
# Processing track: CANDYWINE by PRIADHS FEAT NASYA...
# Processing track: KARENA KUSUKA DIRIMU by RAN...
# Processing track: MALAM TAK BERJUDUL by MONICA CHRISTIANA...
# Processing track: DIA by SAM BIMBO...
# Processing track: KUNIKMATI KEBAIKANMU by BOBBY FEBIAN...
# Processing track: EMPTY HOUSE by GANGGA...
# Processing track: SANG PEMUJA by DUL JAELANI...
# Processing track: HBD MOM by STVE JAY...
# Processing track: JARANAN by NO KOES...
# Processing track: SEKILAS INFO by JASON RANTI...
# Processing track: KUINGIN by BROCKERS...
# Processing track: LUPAHON MA HALLET MI by GAOLS NAIBAHO...
# Processing track: PENYIHIR by QODIR...
# Processing track: TORRO MO DIINGARAN by SALMA MARGARETH...
# Processing track: FOOL by THE ADAMS...
# Processing track: SEKOPI by EDO MARTIN...
# Processing track: SINARI by ANANG DAN KRISDAYANTI...
# Processing track: GASLIGHT by PRIADHS FEAT MARO...
# Processing track: DISTANCE by MALIK...
# Processing track: ROLLIN by INDRAGERSN...
# Processing track: KUPU KUPU BIRU by LA HILA...
# Processing track: TAKDIR KEHIDUPANKU by KOES PLUS...
# Processing track: KU RINDU IBU by EL ALICE...
# Processing track: SITI MARSITOL by BENYAMIN S FEAT. EDDY SUD...
# Processing track: AWKWARD by MONDO GASCARO...
# Processing track: SELALU BERSYUKUR DONG by AMSB FAMILY...
# Processing track: SELAMAT TINGGAL by PUGAR RESTU JULIAN...
# Processing track: A MOTHERS LOVE IN C MINOR by NARHA ANINDYAGUNA...
# Processing track: UBAH WARNAKU MENJADI KUNING DARI BIRU YANG MEMBELENGGU by RUB OF RUB...
# Processing track: SEPARUH HATI by JIKUSTIK...
# Processing track: SEBUAH ANOMALI by FIGURA RENATA...
# Processing track: CUMA BUTUH ITU by AXL HUNILA...
# Processing track: SELESAI by IFA FACHIR, DIMAS WIBISANA...
# Processing track: FLY ME OVER by KAHITNA...
# Processing track: TENTANG CINTA by RAISA...
# Processing track: COWOK SEJATI by HERI YOSELIN...
# Processing track: AKU SELALU ADA by CHRISTIE KAORI...
# Processing track: PAGER KUNING by KOES BERSAUDARA...
# Processing track: SERENATA JIWA LARA by DISKORIA FEAT DIAN SASTRO...
# Processing track: BETTER by NATHANIA WIBOWO...
# Processing track: SATU KOSONG by ALEXA...
# Processing track: BUNGA by KOES PLUS...
# Processing track: BUAH JAMBU by NO KOES...
# Processing track: UPDATE STATUS by MALA AGATHA...
# Processing track: CINTA MELULU by ALEXA...
# Processing track: AKU DAN DIA by KOES PLUS...
# Processing track: GLOWING by ANTI HEROES...
# Processing track: MIMPI INDAHKU by WILLY ANGGAWINATA...
# Processing track: DREAM DANCER by LIGHTCRAFT...
# Processing track: SHEILA by AGUS WISMAN...
# Processing track: RAYAKAN HARI INI by PAUL PARTOHAP, DEABDIL, REMI, AMIRA KARIN...
# Processing track: ANJING URBAN (SANG KORBAN II) by THE BRANDALS...
# Processing track: SAHABATKU BINTANG by KITA-KITA...
# Processing track: PILIH AKU ATAU DIA by THE CHRONICLES OF HAPPINESS RIDE AND SERVICES...
# Processing track: BUANG MANTAN by ERNA ARISMA...
# Processing track: I WANT TO ROCK N ROLL by ARAH...
# Processing track: YOURE ALWAYS THE BEST by ABEL HURAY...
# Processing track: WHYYOUNEEDSPACEIFYOUDONT? by UND BODEVAN...
# Processing track: SAD STORIES by ALEX KUPLE...
# Processing track: PANGGUNG GEMILANG by RARA...
# Processing track: JOMLO HAPPY by SARAS...
# Processing track: MEXICO by KARAN AUJLA...
# Processing track: BILA AKU PULANG by NAFF...
# Processing track: ETUDE 5 by ADI DARMAWAN...
# Processing track: WUJUDKAN by ADDICTIVE...
# Processing track: PERUBAHAN TAK BUTUH RATING by LOKUS...
# Processing track: COME OVER by MIMA...
# Processing track: ADA CERITA by LESTI...
# Processing track: TITIAN SERAMBUT DIBELAH TUJUH by BIMBO...
# Processing track: KU TAK LAKU LAKU by PO3THREE...
# Processing track: MORE THAN FRIENDS by SVMMERDOSE...
# Processing track: TAK TERBATAS by NDC WORSHIP...
# Processing track: BUBUR AYAM by KAPTEN PIPING...
# Processing track: BULAN by FLANELLA...
# Processing track: FLY by CYNATIC...
# Processing track: RASUL HANCURKAN BERHALA by BIMBO...
# Processing track: AFTER DARK by MR.KITTY...
# Processing track: BIASA-BIASA SAJA by NADYA FATIRA...
# Processing track: SEPARUH JIWAKU PERGI by ANANG...
# Processing track: TAHUN 2000 by SAM, DJAKA, IIN...
# Processing track: WIT GEDHANG by KOES BERSAUDARA...
# Processing track: BETTER by BAYU RISA...
# Processing track: CAHAYA by REDO DAENG BADJIE...
# Processing track: LEBIH MENGASIHIMU by JIS MINISTRY...
# Processing track: NANTI by NEAR, MKARTIKAWATI...
# Processing track: CIRCLE by HUJAN ESOK HARI...
# Processing track: BILA TIBA SATU WAKTU by BIBUS...
# Processing track: ORANG MASA DEPAN by RENNY DJAYOESMAN...
# Processing track: TERIMALAH AKU (INSTRUMENTAL) by STVE JAY...
# Processing track: TIGA HARI YANG LALU by FLANELLA...
# Processing track: AJARI AKU by ANIMA...
# Processing track: DOA by THE HERMANSYAH...
# Processing track: 7 PURNAMA by PT MENGGELORA...
# Processing track: RIBUAN SENJA by ANSURYA...
# Processing track: ARGUMENTASI DIMENSI by FOURTWNTY...
# Processing track: SELAMAT TINGGAL by GARBY BAND...
# Processing track: FENOMENA ROMANSA by DIANDRAS...
# Processing track: WAKE UP by NARHA ANINDYAGUNA...
# Processing track: MINGGU MALAM by KOES BERSAUDARA...
# Processing track: SEANDAINYA SEDERHANA by CHASEIRO...
# Processing track: PERGI CINTA by AUDY...
# Processing track: DISTANCE by ASTERISKA...
# Processing track: MARI BERNYANYI by KOES PLUS...
# Processing track: WAKE ME UP by HAVINHELL...
# Processing track: YAKIN BAHAGIA by MARIA SIMORANGKIR...
# Processing track: INAGURASI by OM PMR (PENGANTAR MINUM RACUN)...
# Processing track: CINTA by SOUND DA' CLAN...
# Processing track: HANYA KEPADAKU by KOES BERSAUDARA...
# Processing track: CINTA SEMPURNA by CONNECT WORSHIP,BOBBY FEBIAN,GRACIA THOMAS...
# Processing track: PENANTIAN by GARDIKA GIGIH PRADIPTA...
# Processing track: INA by MAN...
# Processing track: CANDU DUNIAWI by NAIF...
# Processing track: SINGING PIXIE by SHERINA...
# Processing track: THE SWEET NIGHTMARE by PUTI CHITARA...
# Processing track: ENTER THE SPIDER by ZEKE KHASELI...
# Processing track: CINTA TAK BERARAH by ADY...
# Processing track: WHO TOOK MY MONEY by ANDRE HARIHANDOYO & SONIC PEOPLE...
# Processing track: SAKIT HATI by SETIA...
# Processing track: TAK SEINDAH HARAP by WIDEKS...
# Processing track: LOVE YOU LONGER by RAISA...
# Processing track: TAK TERSISA by ELEMENT...
# Processing track: KUSEMATKAN CINTAKU by DHANIS MARTIN...
# Processing track: KUINGIN KAU SELALU ADA by NAFF...
# Processing track: I AM MORE by MAUDY AYUNDA...
# Processing track: DAMBA by MARION JOLA...
# Processing track: PANGERAN CINTA by ST12...
# Processing track: SURAT KALENG by DIDITSAAD...
# Processing track: COBA LAGI by RUTH SAHANAYA...
# Processing track: PADANG LUAS by KOES PLUS...
# Processing track: RINTANGAN by KARIMATA, LYDIA NURSAID, DIAN P P...
# Processing track: NGUPI by BENYAMIN S...
# Processing track: BALADA INSAN MUDA by DIKSORIA...
# Processing track: HEARTLESS by NEONOMORA...
# Processing track: OTHER TIMES by AUFA...
# Processing track: KAU LAYAK by CONNECT WORSHIP, BOBBY FEBIAN...
# Processing track: MR. RIGHT by YOLANDA THEODORA...
# Processing track: MALIOBORO NINGGAL CERITO by ARIBOWOID, GORAT.ID...
# Processing track: PIPE TOMAHAWK by JEMIMA...
# Processing track: MAJU FRI, MAJULAH NEGERI by RIZKA ZAHRA TAMIRA...
# Processing track: SIANA by TCASH...
# Processing track: KATA TETANGGA by RCKA...
#                               track_name         artist_name  \
# 0                         BERTAHAN HIDUP              8 BALL
# 1                  Kemana Saja Kau Pergi           Koes Plus
# 2                         TARI SELENDANG           KOES PLUS
# 3    Main Theme From '13 Bom di Jakarta'          Abel Huray
# 4                   Tangisan Ibu Pertiwi           Strangers
# ..                                   ...                 ...
# 352             Malioboro Ninggal Cerito           Aribowoid
# 353                        Pipe Tomahawk              Jemima
# 354          Majulah FRI, Majulah Negeri  Rizka Zahra Tamira
# 355                                SIANA               TCASH
# 356                        Kata Tetangga                RCKA
#
#            spotify_track_id          isrc  \
# 0                       NaN           NaN
# 1    6AVBDYXyuzy6qEqiqOIifQ  IDA511800251
# 2                       NaN           NaN
# 3    6iy6pccEKiQ0cp4NvqW7HG  IDA172330296
# 4    3p1DTkBr2owMxr6gZUVGdV  ushm20871973
# ..                      ...           ...
# 352  6X3xlDBobIsf0VO8dlcNwz  IDA832400306
# 353  550NrkyvtX2U3IcB3iTCZ4  GB5EA1701125
# 354  2vvI57iAwaTqgMjlvdp40p  FRX872167710
# 355                     NaN           NaN
# 356  3FQJEUjkraEOr6Pbn8J69m  GXBAV2246572
#
#                                             album_name release_date
# 0                                                  NaN          NaN
# 1                        Mustika Keroncong Koes Plus 1   2016-02-02
# 2                                                  NaN          NaN
# 3    13 Bom Di Jakarta : Music From The Motion Picture   2023-12-28
# 4                            Everything Goes Automatic   2008-07-28
# ..                                                 ...          ...
# 352                           Malioboro Ninggal Cerito   2024-02-08
# 353                                       XXX (Side A)         2017
# 354                                          MAHASISWA   2021-11-30
# 355                                                NaN          NaN
# 356                                      Kata Tetangga   2024-06-27
#
# [357 rows x 6 columns]
# Metadata saved to combined_spotify_metadata.csv

# %%
import os
import googleapiclient.discovery
import pandas as pd

class YouTubeMetadataRetriever:
    def __init__(self, youtube_api_keys):
        """
        Initialize the YouTube metadata retriever with multiple API keys for rotation
        
        :param youtube_api_keys: List of YouTube API keys
        """
        self.youtube_api_keys = youtube_api_keys
        self.current_key_index = 0
        self.youtube_client = self._get_client()

    def _get_client(self):
        """
        Initialize the YouTube client with the current API key
        """
        return googleapiclient.discovery.build(
            "youtube", "v3", developerKey=self.youtube_api_keys[self.current_key_index]
        )

    def _rotate_key(self):
        """
        Rotate to the next API key and reinitialize the client
        """
        self.current_key_index = (self.current_key_index + 1) % len(self.youtube_api_keys)
        print(f"Rotating to API key {self.current_key_index + 1} of {len(self.youtube_api_keys)}...")
        self.youtube_client = self._get_client()

    def search_youtube_video(self, query):
        """
        Search for a video on YouTube and retrieve its metadata
        """
        while True:
            try:
                request = self.youtube_client.search().list(
                    q=query, 
                    part="snippet",
                    maxResults=1,
                    type="video"
                )
                response = request.execute()
                
                if response['items']:
                    video = response['items'][0]
                    snippet = video['snippet']
                    return {
                        'youtube_video_id': video['id']['videoId'],
                        'title': snippet['title'],
                        'description': snippet.get('description', 'N/A'),
                        'channel_title': snippet['channelTitle'],
                        'publish_date': snippet['publishedAt']
                    }
                return None
            except googleapiclient.errors.HttpError as e:
                error_details = e.error_details if hasattr(e, 'error_details') else str(e)
                print(f"Error searching YouTube video: {error_details}")
                if "quotaExceeded" in str(e):
                    self._rotate_key()  # Rotate to the next API key
                else:
                    break
            except Exception as e:
                print(f"An unexpected error occurred: {e}")
                break

    def retrieve_video_metadata(self, tracks):
        """
        Retrieve metadata for multiple tracks from YouTube
        """
        metadata_results = []
        for track_info in tracks:
            track_name = track_info.get('track_name')
            artist_name = track_info.get('artist_name')
            print(f"Processing track: {track_name} by {artist_name}...")
            
            youtube_query = f"{track_name} {artist_name}"
            youtube_metadata = self.search_youtube_video(youtube_query)
            
            combined_metadata = {
                'track_name': track_name,
                'artist_name': artist_name,
                **((youtube_metadata or {}) if youtube_metadata else {})
            }
            metadata_results.append(combined_metadata)
        return pd.DataFrame(metadata_results)

def main():
    # List of YouTube API keys
    YOUTUBE_API_KEYS = [os.getenv('YOUTUBE_API_KEY_1'), os.getenv('YOUTUBE_API_KEY_2'), os.getenv('YOUTUBE_API_KEY_3')]
    
    # Initialize retriever
    retriever = YouTubeMetadataRetriever(YOUTUBE_API_KEYS)

    # Load CSV file as track input
    csv_file_path = '[DE TS] Song Catalog Data - Data.csv'
    try:
        # Load the CSV file
        song_data = pd.read_csv(csv_file_path)
        print("CSV file loaded successfully!")
        
        # Rename columns to match the required format
        tracks_to_search = song_data.rename(columns={
            'ORIGINAL ARTIST': 'artist_name',
            'SONG TITLE': 'track_name'
        })[['track_name', 'artist_name']].dropna()
        
        print("Formatted track list for search:")
        print(tracks_to_search.head())
        
    except Exception as e:
        print(f"Error loading CSV file: {e}")
        return
    
    # Retrieve metadata
    metadata_df = retriever.retrieve_video_metadata(tracks_to_search.to_dict('records'))
    print(metadata_df)

    # Save to CSV
    output_file = 'combined_youtube_metadata.csv'
    metadata_df.to_csv(output_file, index=False)
    print(f"Metadata saved to {output_file}")

if __name__ == '__main__':
    main()
# Out:
# CSV file loaded successfully!
# Formatted track list for search:
#                            track_name artist_name
# 0                      BERTAHAN HIDUP      8 BALL
# 4                              KEMANA   KOES PLUS
# 10                     TARI SELENDANG   KOES PLUS
# 11  MAIN THEME FROM 13 BOM DI JAKARTA  ABEL HURAY
# 12               TANGISAN IBU PERTIWI   STRANGERS
# Processing track: BERTAHAN HIDUP by 8 BALL...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 1 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 2 of 3...
# Error searching YouTube video: [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]
# Rotating to API key 3 of 3...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 126
#     123     print(f"Metadata saved to {output_file}")
#     125 if __name__ == '__main__':
# --> 126     main()
#
# Cell In[2], line 117, in main()
#     114     return
#     116 # Retrieve metadata
# --> 117 metadata_df = retriever.retrieve_video_metadata(tracks_to_search.to_dict('records'))
#     118 print(metadata_df)
#     120 # Save to CSV
#
# Cell In[2], line 79, in YouTubeMetadataRetriever.retrieve_video_metadata(self, tracks)
#      76 print(f"Processing track: {track_name} by {artist_name}...")
#      78 youtube_query = f"{track_name} {artist_name}"
# ---> 79 youtube_metadata = self.search_youtube_video(youtube_query)
#      81 combined_metadata = {
#      82     'track_name': track_name,
#      83     'artist_name': artist_name,
#      84     **((youtube_metadata or {}) if youtube_metadata else {})
#      85 }
#      86 metadata_results.append(combined_metadata)
#
# Cell In[2], line 44, in YouTubeMetadataRetriever.search_youtube_video(self, query)
#      37 try:
#      38     request = self.youtube_client.search().list(
#      39         q=query,
#      40         part="snippet",
#      41         maxResults=1,
#      42         type="video"
#      43     )
# ---> 44     response = request.execute()
#      46     if response['items']:
#      47         video = response['items'][0]
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/httplib2/__init__.py:1724, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1722             content = b""
#    1723         else:
# -> 1724             (response, content) = self._request(
#    1725                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1726             )
#    1727 except Exception as e:
#    1728     is_timeout = isinstance(e, socket.timeout)
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/httplib2/__init__.py:1444, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1441 if auth:
#    1442     auth.request(method, request_uri, headers, body)
# -> 1444 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1446 if auth:
#    1447     if auth.response(response, body):
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/httplib2/__init__.py:1366, in Http._conn_request(self, conn, request_uri, method, body, headers)
#    1364 try:
#    1365     if conn.sock is None:
# -> 1366         conn.connect()
#    1367     conn.request(method, request_uri, body, headers)
#    1368 except socket.timeout:
#
# File ~/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/httplib2/__init__.py:1156, in HTTPSConnectionWithTimeout.connect(self)
#    1154 if has_timeout(self.timeout):
#    1155     sock.settimeout(self.timeout)
# -> 1156 sock.connect((self.host, self.port))
#    1158 self.sock = self._context.wrap_socket(sock, server_hostname=self.host)
#    1160 # Python 3.3 compatibility: emulate the check_hostname behavior
#
# KeyboardInterrupt:

# %%
import os
os.getenv('YOUTUBE_API_KEY_3')
# Out:
# 'AIzaSyDcPwgTEBvg35K3r-s9wRQx0fk7a4G8IcE'

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import googleapiclient.discovery
import pandas as pd

def init_spotify_client(client_id, client_secret):
    """Initialize Spotify client"""
    credentials_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    return spotipy.Spotify(client_credentials_manager=credentials_manager)

def init_youtube_client(api_key):
    """Initialize YouTube client"""
    return googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

def search_spotify_track(spotify_client, track_name, artist_name):
    """Search for a track on Spotify and retrieve its metadata"""
    try:
        results = spotify_client.search(
            q=f'track:{track_name} artist:{artist_name}',
            type='track',
            limit=1
        )
        if results['tracks']['items']:
            track = results['tracks']['items'][0]
            return {
                'spotify_track_id': track['id'],
                'isrc': track['external_ids'].get('isrc', 'N/A'),
                'spotify_track_name': track['name'],
                'spotify_artist_name': track['artists'][0]['name'],
                'album_name': track['album']['name'],
                'release_date': track['album']['release_date']
            }
        return None
    except Exception as e:
        print(f"Error searching Spotify track: {e}")
        return None

def search_youtube_video(youtube_client, query, youtube_api_keys, current_key_index=0):
    """Search for a video on YouTube and retrieve its metadata"""
    try:
        request = youtube_client.search().list(
            q=query,
            part="snippet",
            maxResults=1,
            type="video"
        )
        response = request.execute()
        
        if response['items']:
            video = response['items'][0]
            snippet = video['snippet']
            return {
                'youtube_video_id': video['id']['videoId'],
                'youtube_title': snippet['title'],
                'youtube_description': snippet.get('description', 'N/A'),
                'youtube_channel_title': snippet['channelTitle'],
                'youtube_publish_date': snippet['publishedAt']
            }
        return None
    except googleapiclient.errors.HttpError as e:
        if "quotaExceeded" in str(e):
            # Rotate to next API key
            new_key_index = (current_key_index + 1) % len(youtube_api_keys)
            print(f"Rotating to API key {new_key_index + 1} of {len(youtube_api_keys)}...")
            new_client = init_youtube_client(youtube_api_keys[new_key_index])
            # Retry with new client
            return search_youtube_video(new_client, query, youtube_api_keys, new_key_index)
        print(f"YouTube API error: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

def process_track(spotify_client, youtube_client, track_info, youtube_api_keys):
    """Process a single track and get metadata from both platforms"""
    track_name = track_info.get('track_name')
    artist_name = track_info.get('artist_name')
    print(f"\nProcessing track: {track_name} by {artist_name}...")
    
    # Get Spotify metadata
    spotify_metadata = search_spotify_track(spotify_client, track_name, artist_name)
    
    # Get YouTube metadata
    youtube_query = f"{track_name} {artist_name}"
    youtube_metadata = search_youtube_video(youtube_client, youtube_query, youtube_api_keys)
    
    # Combine all metadata
    return {
        'original_track_name': track_name,
        'original_artist_name': artist_name,
        **(spotify_metadata if spotify_metadata else {}),
        **(youtube_metadata if youtube_metadata else {})
    }

# Load credentials
SPOTIFY_CLIENT_ID = os.getenv('SPOTIFY_CLIENT_ID')
SPOTIFY_CLIENT_SECRET = os.getenv('SPOTIFY_CLIENT_SECRET')
YOUTUBE_API_KEYS = [
    os.getenv('YOUTUBE_API_KEY_1'),
    os.getenv('YOUTUBE_API_KEY_2'),
    os.getenv('YOUTUBE_API_KEY_3')
]

# Initialize clients
spotify_client = init_spotify_client(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET)
youtube_client = init_youtube_client(YOUTUBE_API_KEYS[0])

try:
    # Load and prepare data
    csv_file_path = '[DE TS] Song Catalog Data - Data.csv'
    song_data = pd.read_csv(csv_file_path)
    print("CSV file loaded successfully!")
    
    # Prepare tracks data
    tracks_to_search = song_data.rename(columns={
        'ORIGINAL ARTIST': 'artist_name',
        'SONG TITLE': 'track_name'
    })[['track_name', 'artist_name']].dropna()
    
    print("Formatted track list for search:")
    print(tracks_to_search.head())
    
    # Process all tracks
    metadata_results = [
        process_track(spotify_client, youtube_client, track, YOUTUBE_API_KEYS)
        for track in tracks_to_search.to_dict('records')
    ]
    
    # Convert to DataFrame
    metadata_df = pd.DataFrame(metadata_results)
    print("\nCombined metadata retrieved:")
    print(metadata_df)
    
    # Save results
    output_file = 'combined_music_metadata.csv'
    metadata_df.to_csv(output_file, index=False)
    print(f"\nMetadata saved to {output_file}")

except Exception as e:
    print(f"Error processing data: {e}")
# Out:
# /Users/Intan/Documents/ghaly/mme/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# CSV file loaded successfully!
# Formatted track list for search:
#                            track_name artist_name
# 0                      BERTAHAN HIDUP      8 BALL
# 4                              KEMANA   KOES PLUS
# 10                     TARI SELENDANG   KOES PLUS
# 11  MAIN THEME FROM 13 BOM DI JAKARTA  ABEL HURAY
# 12               TANGISAN IBU PERTIWI   STRANGERS
#
# Processing track: BERTAHAN HIDUP by 8 BALL...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
# Rotating to API key 1 of 3...
# Rotating to API key 2 of 3...
# Rotating to API key 3 of 3...
